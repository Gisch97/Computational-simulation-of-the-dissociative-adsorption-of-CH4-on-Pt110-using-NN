# %% [markdown]
# # Lectura de datos e import de librerías

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.style.use('classic')
sns.set_theme(style="whitegrid")
paletteE =['#00377e', '#006B8F', '#06889B', '#FEAE6C', '#FE6C31', '#F93414']
paletteT =['#011F51', '#06889B',  '#FE6C31']

sns.set_palette(palette=paletteE)
X = [ 0.6, 1,     1.4]
Ystick = [ 0.0123 ,0.069, 0.148]
Yad = [ 0.224,  0.05,  0.01 ]

# %%
MD = pd.read_csv('data/02 - NN15 sheets/MDNN15.csv')

# %% [markdown]
# # Analisis RS

# %%
nnini_stick = [0.00717249555423829, 0.0488, 0.095]
nn15_stick = [0.0066875, 0.042, 0.139]


Yad = [ 0.224,  0.05,  0.01 ]
nnini_ad = [0.129816241849437,  0.0176,  0.006]
nn15_ad = [0.2913125, 0.0548, 0.01]

# %%
fig,ax = plt.subplots(figsize=(12,8))

ax.plot(X, Ystick, color='red', linestyle='--', marker='o'      , label='stick Nicolas')
ax.plot(X, nnini_stick, color='blue', linestyle='--', marker='o', label='stick NNini')

ax.plot(X, Yad, color='orange', linestyle='--', marker='o', label='ad Nicolas')
ax.plot(X, nnini_ad, color='cyan', linestyle='--', marker='o', label='ad NNini')

ax.set_ylim(0.001,1)
ax.set_xlim(0.5,1.5)
ax.set_yscale('log')
ax.set_xlabel(f'Energia de incidencia $Ei [eV]$')
ax.set_ylabel('Probabilidad de sticking/adsorcion disociativo')
ax.set_title('Comparación NNini vs NN Nicolas')

ax.grid(visible=True, which='minor',alpha=0.4)
ax.grid(visible=True, which='major')
ax.legend()

# %%
fig,ax = plt.subplots(figsize=(12,8))

ax.plot(X, Ystick, color='red', linestyle='--', marker='o'      , label='stick Nicolas')
ax.plot(X, nn15_stick, color='blue', linestyle='--', marker='o', label='stick NN15')

ax.plot(X, Yad, color='orange', linestyle='--', marker='o', label='ad Nicolas')
ax.plot(X, nn15_ad, color='cyan', linestyle='--', marker='o', label='ad NN15')

ax.set_ylim(0.001,1)
ax.set_xlim(0.5,1.5)
ax.set_yscale('log')
ax.set_xlabel(f'Energia de incidencia $Ei [eV]$')
ax.set_ylabel('Probabilidad de sticking/adsorcion disociativo')
ax.set_title('Comparación NN15 vs NN Nicolas')

ax.grid(visible=True, which='minor',alpha=0.4)
ax.grid(visible=True, which='major')
ax.legend()

# %% [markdown]
# [# Analisis MD

# %%
MD_Ei0_6 = MD.query('Ei == 0.6')
MD_Ei0_6
# Out:
#       T   Ei   nint  nrefl  nstick  nstickearly  nsticklate  nstickpat
# 1    50  0.6   9641   3754      48            0          10          0  \
# 7   300  0.6  10000   4633      56            0          10          0
# 13  550  0.6  10000   4769      65            0           6          0
#
#     nadmol  nprobl    tot     Prefl    Pstick    Padmol
# 1     5829       0   9641  0.389379  0.006016  0.604605
# 7     5301       0  10000  0.463300  0.006600  0.530100
# 13    5160       0  10000  0.476900  0.007100  0.516000

# %%
MD_Ei1_0 = MD.query('Ei == 1.0')
MD_Ei1_0
# Out:
#       T   Ei   nint  nrefl  nstick  nstickearly  nsticklate  nstickpat
# 3    50  1.0  10000   6388     354            0          38          0  \
# 9   300  1.0   9301   6529     372            0          40          0
# 15  550  1.0  10000   7189     415            0          50          0
#
#     nadmol  nprobl    tot     Prefl    Pstick    Padmol
# 3     3220       0  10000  0.638800  0.039200  0.322000
# 9     2360       0   9301  0.701968  0.044296  0.253736
# 15    2346       0  10000  0.718900  0.046500  0.234600

# %%
MD_Ei1_4 = MD.query('Ei == 1.4')
MD_Ei1_4
# Out:
#       T   Ei   nint  nrefl  nstick  nstickearly  nsticklate  nstickpat
# 5    50  1.4  10000   7620    1099            0          95          0  \
# 11  300  1.4  10000   7809    1144            0          88          0
# 17  550  1.4   9604   7480    1128            0          91          1
#
#     nadmol  nprobl    tot     Prefl    Pstick    Padmol
# 5     1186       0  10000  0.762000  0.119400  0.118600
# 11     959       0  10000  0.780900  0.123200  0.095900
# 17     904       0   9604  0.778842  0.126926  0.094127

# %%
# fig, ax = plt.subplots(1,1, figsize=(10,6))

# MD_Ei0_6.plot(x='Temperatura', y='Prefl', ax=ax,  linestyle='--', marker='o',color='blue', label='0.6')
# MD_Ei1_0.plot(x='Temperatura', y='Prefl', ax=ax,  linestyle='--', marker='o',color='orange', label='1.0')
# MD_Ei1_4.plot(x='Temperatura', y='Prefl', ax=ax,  linestyle='--', marker='o',color='red', label='1.4')
# ax.axhline(y=NNini.Prefl[0], color = 'blue', alpha=0.3, linestyle='--', label='RS ini 0.6')
# ax.axhline(y=NNini.Prefl[1], color = 'orange', alpha=0.3, linestyle='--', label='RS ini 1.0')
# ax.axhline(y=NNini.Prefl[2], color = 'red', alpha=0.3, linestyle='--', label='RS ini 1.4')


# ax.set_title('Prefl')
# ax.set_ylabel('Probabilidad')
# ax.legend(title='Ei', bbox_to_anchor=(1.2,1))
# plt.show()

# %%
# fig, ax = plt.subplots(1,2, figsize=(16,6))


# MD_Ei0_6.plot(x='Temperatura', y='Pstick', ax=ax[0],  linestyle='--', marker='o',color='blue', label='0.6')
# MD_Ei1_0.plot(x='Temperatura', y='Pstick', ax=ax[0],  linestyle='--', marker='o',color='orange', label='1.0')
# MD_Ei1_4.plot(x='Temperatura', y='Pstick', ax=ax[0],  linestyle='--', marker='o',color='red', label='1.4')
# ax[0].axhline(y=Ystick[0], color = 'blue', alpha=0.3, label='RS ref 0.6')
# ax[0].axhline(y=Ystick[1], color = 'orange', alpha=0.3, label='RS ref 1.0')
# ax[0].axhline(y=Ystick[2], color = 'red', alpha=0.3, label='RS ref 1.4')

# ax[0].axhline(y=NNini.Pstick[0], color = 'blue', alpha=0.3, linestyle='--', label='RS ini 0.6')
# ax[0].axhline(y=NNini.Pstick[1], color = 'orange', alpha=0.3, linestyle='--', label='RS ini 1.0')
# ax[0].axhline(y=NNini.Pstick[2], color = 'red', alpha=0.3, linestyle='--', label='RS ini 1.4')

# ax[0].set_title('Pstick')
# ax[0].set_ylabel('Probabilidad')


# MD_Ei0_6.plot(x='Temperatura', y='Pstick', ax=ax[1],  linestyle='--', marker='o',color='blue', label='0.6')
# MD_Ei1_0.plot(x='Temperatura', y='Pstick', ax=ax[1],  linestyle='--', marker='o',color='orange', label='1.0')
# MD_Ei1_4.plot(x='Temperatura', y='Pstick', ax=ax[1],  linestyle='--', marker='o',color='red', label='1.4')
# ax[1].axhline(y=Ystick[0], color = 'blue', alpha=0.3, label='RS ref 0.6')
# ax[1].axhline(y=Ystick[1], color = 'orange', alpha=0.3, label='RS ref 1.0')
# ax[1].axhline(y=Ystick[2], color = 'red', alpha=0.3, label='RS ref 1.4')

# ax[1].axhline(y=NNini.Pstick[0], color = 'blue', alpha=0.3, linestyle='--', label='RS ini 0.6')
# ax[1].axhline(y=NNini.Pstick[1], color = 'orange', alpha=0.3, linestyle='--', label='RS ini 1.0')
# ax[1].axhline(y=NNini.Pstick[2], color = 'red', alpha=0.3, linestyle='--', label='RS ini 1.4')

# ax[1].set_title('Pstick')
# ax[1].set_ylabel('Probabilidad log')
# ax[1].set_yscale('log')
# ax[1].grid(visible=True, which='minor',alpha=0.4)
# ax[1].grid(visible=True, which='major')
# ax[1].legend(title='Ei', bbox_to_anchor=(1.3,1))
# plt.show()

# %%
# fig, ax = plt.subplots(1,2, figsize=(16,6))

# MD_Ei0_6.plot(x='Temperatura', y='Padmol', ax=ax[0],  linestyle='--', marker='o',color='blue', label='0.6')
# MD_Ei1_0.plot(x='Temperatura', y='Padmol', ax=ax[0],  linestyle='--', marker='o',color='orange', label='1.0')
# MD_Ei1_4.plot(x='Temperatura', y='Padmol', ax=ax[0],  linestyle='--', marker='o',color='red', label='1.4')
# ax[0].axhline(y=Yad[0], color = 'blue', alpha=0.3, label='RS ref 0.6')
# ax[0].axhline(y=Yad[1], color = 'orange', alpha=0.3, label='RS ref 1.0')
# ax[0].axhline(y=Yad[2], color = 'red', alpha=0.3, label='RS ref 1.4')


# ax[0].axhline(y=NNini.Padmol[0], color = 'blue', alpha=0.3, linestyle='--', label='RS ini 0.6')
# ax[0].axhline(y=NNini.Padmol[1], color = 'orange', alpha=0.3, linestyle='--', label='RS ini 1.0')
# ax[0].axhline(y=NNini.Padmol[2], color = 'red', alpha=0.3, linestyle='--', label='RS ini 1.4')

# fig.suptitle('Padmol')
# ax[0].set_ylabel('Probabilidad')


# MD_Ei0_6.plot(x='Temperatura', y='Padmol', ax=ax[1],  linestyle='--', marker='o',color='blue', label='0.6')
# MD_Ei1_0.plot(x='Temperatura', y='Padmol', ax=ax[1],  linestyle='--', marker='o',color='orange', label='1.0')
# MD_Ei1_4.plot(x='Temperatura', y='Padmol', ax=ax[1],  linestyle='--', marker='o',color='red', label='1.4')
# ax[1].axhline(y=Yad[0], color = 'blue', alpha=0.3, label='RS ref 0.6')
# ax[1].axhline(y=Yad[1], color = 'orange', alpha=0.3, label='RS ref 1.0')
# ax[1].axhline(y=Yad[2], color = 'red', alpha=0.3, label='RS ref 1.4')


# ax[1].axhline(y=NNini.Padmol[0], color = 'blue', alpha=0.3, linestyle='--', label='RS ini 0.6')
# ax[1].axhline(y=NNini.Padmol[1], color = 'orange', alpha=0.3, linestyle='--', label='RS ini 1.0')
# ax[1].axhline(y=NNini.Padmol[2], color = 'red', alpha=0.3, linestyle='--', label='RS ini 1.4')

# ax[1].set_yscale('log')
# ax[1].grid(visible=True, which='minor',alpha=0.4)
# ax[1].grid(visible=True, which='major')
# ax[1].legend(title='Ei', bbox_to_anchor=(1.3,1))
# ax[1].set_ylabel('Probabilidad [log]')
# plt.show()

# %%
# sns.lineplot(data=MD, x='Ei', y='Pstick', hue='Temperatura', marker='o', linestyle='--')
# plt.plot(X, Ystick, color='black', label='RS ref')
# plt.xlim(0.55, 1.45)

# plt.title('Pstick')
# plt.ylabel('Probabilidad log')
# plt.yscale('log')
# plt.legend(title='Temperatura', bbox_to_anchor=(1.2,1))
# plt.show()

# %%
# sns.lineplot(data=MD, x='Ei', y='Padmol', hue='Temperatura', marker='o', linestyle='--')
# plt.plot(X, Yad, color='black', label='RS ref')
# plt.legend(title='Temperatura', bbox_to_anchor=(1.2,1))
# plt.xlim(0.55, 1.45)
# plt.show()

# %%
# Yrefl = [1 - Yad[0] - Ystick[0],1 - Yad[1] - Ystick[1],1 - Yad[2] - Ystick[2]]
# Yrefl

# %%
# sns.lineplot(data=MD, x='Ei', y='Prefl', hue='Temperatura', marker='o', linestyle='--')
# plt.plot(X, Yrefl, color='black', label='RS ref')
# plt.legend(title='Temperatura', bbox_to_anchor=(1.2,1))
# plt.xlim(0.55, 1.45)
# plt.show()

# %% [markdown]
# # Resultado Final

# %%
MD['1/T'] = 1000/ MD['T']

# %%
fig, ax = plt.subplots(1,2, figsize = (16,6))
sns.lineplot(data=MD, x='1/T', y='Prefl', hue='Ei', marker='o', ax=ax[0], palette=paletteE)
fig.suptitle('Probabilidad de reflexión molecular')
ax[0].legend(bbox_to_anchor=(-0.1,1), title='Ei[eV]')
ax[0].set_xlabel('1 / Temperatura [$K^{-1}$]')
ax[0].set_xlim(0, 22)
sns.lineplot(data=MD, x='Ei', y='Prefl', hue='T', marker='o', ax=ax[1], palette=paletteT)
ax[1].set_xlabel(f'Energía de incidencia [eV]')
ax[1].set_xlim(0.35, 1.45)
ax[1].legend(bbox_to_anchor=(1.2,1), title='T [K]')

# %%
fig, ax = plt.subplots(1,2, figsize = (16,6))
sns.lineplot(data=MD.query('Ei>0.4'), x='1/T', y='Pstick', hue='Ei', marker='o', ax=ax[0], palette=paletteE)
fig.suptitle('Probabilidad de sticking', fontsize=16)
ax[0].legend(bbox_to_anchor=(-0.1,1), title='Ei[eV]')
ax[0].set_xlabel('1000 / $T_{sf}$ [$K^{-1}$]')
ax[0].set_xlim(0, 22)
sns.lineplot(data=MD.query('Ei>0.4'), x='Ei', y='Pstick', hue='T', marker='o', ax=ax[1], palette=paletteT)
ax[1].set_yscale('log')
ax[1].set_xlabel(f'Energía de incidencia [eV]')
ax[1].set_xlim(0.55, 1.45)
ax[1].set_ylim(0.005, 0.3)
ax[1].grid(which='minor')
ax[1].minorticks_on()
ax[1].legend(loc='upper left', title='T [K]')
fig.tight_layout()
plt.show()
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_22952\2833200084.py:2: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sns.lineplot(data=MD.query('Ei>0.4'), x='1/T', y='Pstick', hue='Ei', marker='o', ax=ax[0], palette=paletteE)

# %%
fig, ax = plt.subplots(1,2, figsize = (16,6))
sns.lineplot(data=MD, x='1/T', y='Pstick', hue='Ei', marker='o', ax=ax[0], palette=paletteE)
fig.suptitle('Probabilidad de sticking')
ax[0].legend(bbox_to_anchor=(-0.1,1), title='Ei[eV]')

ax[0].set_yscale('log')
ax[0].set_xlabel('1000 / T_s ')
ax[0].set_ylabel(f'Pstick (log)')
ax[0].set_xlim(0, 22)
sns.lineplot(data=MD, x='Ei', y='Pstick', hue='T', marker='o', ax=ax[1], palette=paletteT)
ax[1].set_yscale('log')
ax[1].set_ylabel(f'Pstick (log)')
ax[1].set_xlabel(f'Energía de incidencia [eV]')
ax[1].set_xlim(0.35, 1.45)
ax[1].legend(bbox_to_anchor=(1.2,1), title='T [K]')

# %%
fig, ax = plt.subplots(1,2, figsize = (16,6))
sns.lineplot(data=MD, x='1/T', y='Padmol', hue='Ei', marker='o', ax=ax[0], palette=paletteE)
fig.suptitle('Probabilidad de Adsorción Molecular', fontsize=16)
ax[0].legend(bbox_to_anchor=(-0.1,1), title='Ei[eV]')
ax[0].set_xlabel('1000 / $T_{sf}$ [$K^{-1}$]')
ax[0].set_xlim(0, 22)
sns.lineplot(data=MD, x='Ei', y='Padmol', hue='T', marker='o', ax=ax[1], palette=paletteT)
# ax[1].set_yscale('log')
ax[1].set_xlabel(f'Energía de incidencia [eV]')
ax[1].set_xlim(0.35, 1.45)
# ax[1].set_ylim(0.09, 1)
# ax[1].grid(which='minor')
ax[1].minorticks_on()
ax[1].legend(loc='upper right', title='T [K]')
fig.tight_layout()
plt.show()

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Suponiendo que ya tienes la tabla MD cargada en un DataFrame llamado MD

# # Crea la figura y los ejes
# fig, ax = plt.subplots(1, 2, figsize=(16, 6))

# # Primer gráfico
# sns.lineplot(data=MD, x='T', y='Pstick', hue='Ei', marker='o', style='Ei', dashes=False,
#              ax=ax[0], palette='husl', markersize=8, hue_order=sorted(MD['Ei'].unique()))
# fig.suptitle('Probabilidad de sticking')
# ax[0].legend(bbox_to_anchor=(-0.1, 1), title='Ei[eV]')

# # Escala logarítmica en el eje y
# ax[0].set_yscale('log')
# ax[0].set_xlabel(f'Temperatura [K]')
# ax[0].set_ylabel(f'Pstick (log)')

# # Segundo gráfico
# sns.lineplot(data=MD, x='Ei', y='Pstick', hue='T', marker='o', style='T',
#              ax=ax[1], palette='viridis', markersize=8, hue_order=sorted(MD['T'].unique()))
# ax[1].set_yscale('log')
# ax[1].set_ylabel(f'Pstick (log)')
# ax[1].set_xlabel(f'Energía de incidencia [eV]')
# ax[1].set_xlim(0.35, 1.45)
# ax[1].legend(bbox_to_anchor=(1.2, 1), title='T [K]')

# # Modifica el estilo del punto Ei = 0.4 y T = 300 K en el segundo gráfico
# point_to_modify = (MD['Ei'] == 0.4) & (MD['T'] == 300)
# ax[1].lines[point_to_modify][0].set_markerfacecolor('white')
# ax[1].lines[point_to_modify][0].set_markersize(8)
# ax[1].lines[point_to_modify][0].set_markeredgecolor('black')
# ax[1].lines[point_to_modify][0].set_linestyle('--')

# # Muestra la gráfica
# plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize = (16,6))
sns.lineplot(data=MD, x='1/T', y='Prefl', hue='Ei', marker='o', ax=ax[0], palette=paletteE)
fig.suptitle('Probabilidad de Reflexión', fontsize=16)
ax[0].legend(bbox_to_anchor=(-0.1,1), title='Ei[eV]')
ax[0].set_xlabel('1000 / $T_{sf}$ [$K^{-1}$]')
ax[0].set_xlim(0, 22)
sns.lineplot(data=MD, x='Ei', y='Prefl', hue='T', marker='o', ax=ax[1], palette=paletteT)
# ax[1].set_yscale('log')
ax[1].set_xlabel(f'Energía de incidencia [eV]')
ax[1].set_xlim(0.35, 1.45)
# ax[1].set_ylim(0.09, 1)
# ax[1].grid(which='minor')
ax[1].minorticks_on()
ax[1].legend(loc='upper left', title='T [K]')
fig.tight_layout()
plt.show()

# %%
sns.lineplot(data=MD.query('Ei > 0.4'), x='Ei', y='Pstick', hue='T', marker='o', linestyle='--',  palette=paletteT)
sns.lineplot(data=MD.query('Ei > 0.4'), x='Ei', y='Padmol', hue='T', marker='o',alpha=0.6, linestyle='-',  palette=paletteT, legend=None)
plt.xlim(0.55,1.45)
plt.ylim(0.005,1)
plt.yscale('log')   
plt.text(1,0.35, 'Adsorción Molecular' , color='red')
plt.text(1,0.03, 'Adsorción Disociativa', color='red')
plt.xlabel('$E_i$ [eV]')
plt.ylabel('Probabilidad')
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='black', alpha=0.5)
plt.legend(bbox_to_anchor=(1.2,1))
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize = (16,6))
sns.lineplot(data=MD, x='1/T', y='Pstick', hue='Ei', marker='o', ax=ax[0], palette=paletteE, legend=False) 
ax[0].set_xlabel('1000 / $T_{sf}$ [$K^{-1}$]')
ax[0].set_title('Adsorción Disociativa')
ax[0].set_xlim(0, 22) 
ax[0].set_ylim(-0.01, 0.15) 

sns.lineplot(data=MD, x='1/T', y='Padmol', hue='Ei', marker='o', ax=ax[1], palette=paletteE, legend=False) 
ax[1].set_xlabel('1000 / $T_{sf}$ [$K^{-1}$]')

ax[1].set_xlim(0, 22) 
ax[1].set_ylim(-0.01, 0.8) 
ax[1].set_title('Adsorción Molecular')

sns.lineplot(data=MD, x='1/T', y='Prefl', hue='Ei', marker='o', ax=ax[2], palette=paletteE) 
ax[2].legend(bbox_to_anchor=(1.21,1), title='Ei[eV]')
ax[2].set_xlabel('1000 / $T_{sf}$ [$K^{-1}$]')
ax[2].set_title('Reflexión')
ax[2].set_xlim(0, 22) 
ax[2].set_ylim(-0.01, 0.8) 
fig.tight_layout()
plt.show()
