# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Slabmotion_TRAIN.xlsx', sheet_name='Sheet2')
df
# Out:
#     Temperatura    NN1    NN2     NN3     NN4     NN5     NN6     NN7     NN8
# 0            50  58009  23057  100000  100000  100000  100000  100000  100000
# 1           100  59515  69315  100000  100000   54378  100000  100000  100000
# 2           150  59052   2040   67391  100000  100000  100000  100000  100000
# 3           200  54308      1  100000    8967   61031  100000  100000  100000
# 4           250   7017      1   78865       1  100000  100000  100000  100000
# 5           300      1      1    6621       1  100000  100000  100000  100000
# 6           350      1      1       1       1   64777  100000  100000  100000
# 7           400      1      1    2288       1   66186  100000  100000  100000
# 8           450      1      1    2155       1  100000  100000  100000  100000
# 9           500      1      1       1       1   59118   21480  100000  100000
# 10          550      1      1       1       1  100000   30571   66991  100000
# 11          600      1      1       1       1   25883     196    3642  100000
# 12          650      1      1       1       1   12141     164    1872  100000
# 13          700      1      1       1       1   25651       1     185  100000
# 14          750      1      1       1       1    1010       1      35  100000

# %%
for col in df.columns:
    if col == 'Temperatura':
        continue
    print(col)
# Out:
# NN1
# NN2
# NN3
# NN4
# NN5
# NN6
# NN7
# NN8

# %%
ax = plt.subplot()
for i,col in enumerate(df.columns):
    if col == 'Temperatura':
        continue
    ax.plot(df.Temperatura, df[col], label=col, marker='o', alpha=0.5)
ax.grid()
ax.legend(bbox_to_anchor=(1,1))
